# %% [markdown]
# ### Datenmodell
#
# Beschreibung der Domäne, die auf Basis der relationalen DB gewünscht wird:
#
# > - Über unterschiedliche (auch in Stationen) können Buchungen betätigt werden.
# > - Jede Station hat einen Betreiber
# > - In einer Buchung wird ein Fahrzeug ausgeliehen.
# > - Das Fahrzeug wird von einer Station abgeholt und in einer Station abgegeben
# > - Jede Buchung ist einer Tarifklasse zugeordnet.
# > - Fahrzeuge haben Eigenschaften
# > - Stationen haben Eigenschaften
# > - Tarifklassen haben Eigenschaften
# > - Buchungen haben Eigenschaften
#
# Entscheidungen
#
# > - Fahrzeug-[wird abgeholt]->Station
# > - Fahrzeug-[wird abgegeben]->Station
# > - Buchung-[bezieht sich]->Fahrzeug
# > - Firma-[betreibt]->Station
# > - Firma-[gehoert zu]-> Gruppe
# > - Buchung-[hat]->Tarifklasse
# > - Tarifklasse-[ist untergeordnet zu]->Haupttarif
# > - Fahrzeuge unterscheiden sich durch
# >  - Marke
# >  - Kraftstoff
# > - Buchungen unterscheiden sich durch
# >  - Tarifklasse
# >  - Fahrstrecke
# >  - Buchungsquelle
# > - Tarifklassen unterscheiden sich durch
# >  - Haupttarif

# %%
import pandas as pd
import numpy as np

# %%
def writeDsvFile(df, typeName, delimiter, columnsList, headerList):
    filename = './output/' + typeName + '.dsv'
    df.to_csv(filename, index = False, sep = delimiter, columns = columnsList, header = headerList)
    
def trimName(longName):
    trimmedName = ''
    if longName == np.nan:
        trimmedName = 'nan'
    else:
    #print(longName)
    #print(longName.split())
    #print(longName.split()[0])
    #print(longName[:longName.find(" ")])
        trimmedName = repr(longName).replace(' ', '_').replace('(','').replace(')','').replace('/','')
    #print(trimmedName)
    return trimmedName

# %%
def getLabel(row, nodeName):
    switcher = {
        "CATEGORY": "TARIF",
        "PARENT_CATEGORY": "HAUPTTARIF",
        "BOOKING": "BUCHUNG",
        "VEHICLE": "FAHRZEUG",
        "RENTAL_ZONE": "STATION"
    }
    label = switcher.get(nodeName, 'OBJ')
    if nodeName == 'BOOKING':
        label += ";" + str(row["PARENT_CATEGORY"])
    elif nodeName == 'VEHICLE':
        label += \
                ";" + str(row["VEHICLE_MODEL_TYPE"].upper()) + \
                ";" + str(row["VEHICLE_MANUFACTURER_NAME"].upper()) + \
                ";" + str(row["FUEL_TYPE_NAME"].upper());
    elif nodeName == 'RENTAL_ZONE':
        label += ";" + str(row["TYPE"].upper()) 
        label += ";ACTIVE" if str(row["ACTIVE_X"].upper()) == "JA" else ";INACTIVE"
    return label

# %%
def getRelationshipType(row, types):
    switcher = {
        "CATEGORY": {
                "PARENT_CATEGORY": "GEHOERT_ZU",
            },
        "BOOKING": {
                "VEHICLE": "BEZIEHT_SICH",
            },
    }
    relType = switcher.get(types[0], {}).get(types[1], 'UNDEFINED')
    return relType

# %% [markdown]
# ### Lesen der Tarif-Informationen

# %%
df_cat = pd.read_csv('./datasets/OPENDATA_CATEGORY_CARSHARING.csv', quotechar='"',encoding ='utf-8', sep=';')
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY COMPANY_GROUP
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)   DB Fuhrpark
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)   DB Fuhrpark
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)   DB Fuhrpark
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)   DB Fuhrpark
# 4  100004                            Zubehör  Flinkster (Endkd.)   DB Fuhrpark

# %% [markdown]
# ### Die Tarif-Informationen aufnehmen
#
# > Vorgehensweise:
# > - Wir wollen auch ein Label für die Buchungen realisieren, um für die Analyse eine einfacheres Mittel zu haben.
# >  - Aus dem Grund macht es Sinn, neben den Tarifen auch Haupttarife zu definieren, die dann in einer Buchung als Label aufgeführt wird.
# >   - Deswegen sind folgende Schritte notwendig
# >    - Erster Schritt ist die Reduzierung der Tarifbezeichung auf ein Wort (als Name des Haupttarifs)
# >    - Zweiter Schritt ist die Aufnahme in Buchung als zusätzliche Spalte
# > - Tarif und Haupttarife haben ein festes Label
# > - Teilen sich denselben Nummernsraum als Primärschlüssel

# %% [markdown]
# ### Bearbeitung der Tarifinformationen
#
# > - Label-Info erzeugen
# > - Bezeichnung für die Haupttarif erzeugen
# > - Label für das Haupttarif erzeugen
# > - IDs für die Haupttarife erstellen
# > - Typ der Beziehung zwische Tarif und Haupttarif erstellen

# %%
df_cat['LABEL'] = df_cat.apply(getLabel, axis=1, nodeName='CATEGORY')
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY  \
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)
# 4  100004                            Zubehör  Flinkster (Endkd.)
#
#   COMPANY_GROUP  LABEL
# 0   DB Fuhrpark  TARIF
# 1   DB Fuhrpark  TARIF
# 2   DB Fuhrpark  TARIF
# 3   DB Fuhrpark  TARIF
# 4   DB Fuhrpark  TARIF

# %%
df_cat['PARENT_CATEGORY'] = df_cat.agg({'CATEGORY' : lambda x: x.split()[0].replace('/', '')})
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY  \
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)
# 4  100004                            Zubehör  Flinkster (Endkd.)
#
#   COMPANY_GROUP  LABEL PARENT_CATEGORY
# 0   DB Fuhrpark  TARIF     Werbeklasse
# 1   DB Fuhrpark  TARIF     Kleinklasse
# 2   DB Fuhrpark  TARIF            Mini
# 3   DB Fuhrpark  TARIF   Kompaktklasse
# 4   DB Fuhrpark  TARIF         Zubehör

# %%
df_cat['PARENT_LABEL'] = df_cat.apply(getLabel, axis=1, nodeName='PARENT_CATEGORY')
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY  \
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)
# 4  100004                            Zubehör  Flinkster (Endkd.)
#
#   COMPANY_GROUP  LABEL PARENT_CATEGORY PARENT_LABEL
# 0   DB Fuhrpark  TARIF     Werbeklasse   HAUPTTARIF
# 1   DB Fuhrpark  TARIF     Kleinklasse   HAUPTTARIF
# 2   DB Fuhrpark  TARIF            Mini   HAUPTTARIF
# 3   DB Fuhrpark  TARIF   Kompaktklasse   HAUPTTARIF
# 4   DB Fuhrpark  TARIF         Zubehör   HAUPTTARIF

# %%
df_cat['PARENT_ID'] = df_cat.agg({'HAL_ID' : lambda x: x + 10000})
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY  \
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)
# 4  100004                            Zubehör  Flinkster (Endkd.)
#
#   COMPANY_GROUP  LABEL PARENT_CATEGORY PARENT_LABEL  PARENT_ID
# 0   DB Fuhrpark  TARIF     Werbeklasse   HAUPTTARIF     110000
# 1   DB Fuhrpark  TARIF     Kleinklasse   HAUPTTARIF     110001
# 2   DB Fuhrpark  TARIF            Mini   HAUPTTARIF     110002
# 3   DB Fuhrpark  TARIF   Kompaktklasse   HAUPTTARIF     110003
# 4   DB Fuhrpark  TARIF         Zubehör   HAUPTTARIF     110004

# %%
df_cat['REL_TYPE_CAT_PCAT'] = df_cat.apply(getRelationshipType, axis=1, types=["CATEGORY","PARENT_CATEGORY"])
df_cat.head()
# Out:
#    HAL_ID                           CATEGORY             COMPANY  \
# 0  100000        Werbeklasse (mit Beklebung)  Flinkster (Endkd.)
# 1  100001  Kleinklasse (teilweise ohne Navi)  Flinkster (Endkd.)
# 2  100002         Mini (teilweise ohne Navi)  Flinkster (Endkd.)
# 3  100003                      Kompaktklasse  Flinkster (Endkd.)
# 4  100004                            Zubehör  Flinkster (Endkd.)
#
#   COMPANY_GROUP  LABEL PARENT_CATEGORY PARENT_LABEL  PARENT_ID  \
# 0   DB Fuhrpark  TARIF     Werbeklasse   HAUPTTARIF     110000
# 1   DB Fuhrpark  TARIF     Kleinklasse   HAUPTTARIF     110001
# 2   DB Fuhrpark  TARIF            Mini   HAUPTTARIF     110002
# 3   DB Fuhrpark  TARIF   Kompaktklasse   HAUPTTARIF     110003
# 4   DB Fuhrpark  TARIF         Zubehör   HAUPTTARIF     110004
#
#   REL_TYPE_CAT_PCAT
# 0        GEHOERT_ZU
# 1        GEHOERT_ZU
# 2        GEHOERT_ZU
# 3        GEHOERT_ZU
# 4        GEHOERT_ZU

# %% [markdown]
# ### Header für die Tarif-Elemente
# > categoryID:ID(CATEGORY-ID)|name|:LABEL
#
# > categoryID:ID(CATEGORY-ID)|name|:LABEL

# %% [markdown]
# ### Ausgeben der Quelldateien für Neo4J-Import
#
# > - Tarife
# > - Haupttarife
# > - Beziehung

# %%
# Die Nodes für die Tarife
writeDsvFile(df_cat, 'categories', '|', ['HAL_ID', 'CATEGORY', 'LABEL'], ['categoryID:ID(CATEGORY-ID)','name', ':LABEL'])

# %%
# Die Nodes für die Haupttarife
writeDsvFile(df_cat, 'parent_categories', '|', ['PARENT_ID', 'PARENT_CATEGORY', 'PARENT_LABEL'], ['categoryID:ID(CATEGORY-ID)','name', ':LABEL'])

# %%
# Beziehung zu den Haupttarifen
writeDsvFile(df_cat, 'rel_cat_pcat', '|', ['HAL_ID', 'PARENT_ID', 'REL_TYPE_CAT_PCAT'], [':START_ID(CATEGORY-ID)',':END_ID(CATEGORY-ID)', ':TYPE'])

# %% [markdown]
# ### Lesen der Fahrzeuginformationen

# %%
df_fz = pd.read_csv('./datasets/OPENDATA_VEHICLE_CARSHARING.csv', quotechar='"',encoding ='utf-8', sep=';')
df_fz.head()
# Out:
#    VEHICLE_HAL_ID VEHICLE_MODEL_TYPE VEHICLE_MANUFACTURER_NAME  \
# 0          143031               Auto                      Ford
# 1          146501               Auto                       MCC
# 2          147314               Auto                      Ford
# 3          147382               Auto                      Opel
# 4          147392               Auto                       MCC
#
#   VEHICLE_MODEL_NAME                 VEHICLE_TYPE_NAME                VIN  \
# 0            Transit  2,2 Diesel 63kW !! kein Radio !!  WF0XXXBDFX8R74238
# 1            E-Smart                     E-Smart 30 kW  WME4513911K386156
# 2              Focus              1,6 Diesel 80kW NAVI  WF0SXXGCDSAA82712
# 3              Astra              1,7 Diesel 81kW NAVI  W0L0AHL35B2057645
# 4            E-Smart                     E-Smart 30 kW  WME4513911K448772
#
#   REGISTRATION_PLATE  SERIAL_NUMBER  KW FUEL_TYPE_NAME OWNERSHIP_TYPE  \
# 0           F-R 8018            NaN  63         Diesel  Langzeitmiete
# 1          B-SB 4460            NaN  30          Strom  Langzeitmiete
# 2           F-R 8794            NaN  80         Diesel  Langzeitmiete
# 3           F-R 8829            NaN  81         Diesel  Langzeitmiete
# 4         HH-EM 3019            NaN  30          Strom  Langzeitmiete
#
#   CAPACITY_AMOUNT ACCESS_CONTROL_COMPONENT_TYPE             COMPANY  \
# 0            60 l                           NaN  Flinkster (Endkd.)
# 1             NaN                           NaN  Flinkster (Endkd.)
# 2            52 l                           NaN  Flinkster (Endkd.)
# 3            52 l                           NaN  Flinkster (Endkd.)
# 4             NaN                           NaN  Flinkster (Endkd.)
#
#   COMPANY_GROUP
# 0   DB Fuhrpark
# 1   DB Fuhrpark
# 2   DB Fuhrpark
# 3   DB Fuhrpark
# 4   DB Fuhrpark

# %% [markdown]
# ### Aufnehmen der Fahrzeuginformationen
#
# > Die Fahrzeuge haben sehr viele Eigenschaften. Nur einige davon eignen sich auch als Kategorisierungsmerkmal:
# > - VEHICLE_MODEL_TYPE -> Type
# > - VEHICLE_MANUFACTURER_NAME -> Marke
# > - FUEL_TYPE_NAME -> Kraftstoff
#
# > Andere Eigenschaften werden als Attribut aufgenommen.
#
# > Header für die Fahrzeuginformationen:
#
# > vehicleID:ID(VEHICLE-ID)|modelName|modelDetails|vin|registrationPlate|kw:long|fuelType|ownershipType|company|companyGroup|:LABEL

# %%
df_fz['LABEL'] = df_fz.apply(getLabel, axis=1, nodeName='VEHICLE')
df_fz.head()
# Out:
#    VEHICLE_HAL_ID VEHICLE_MODEL_TYPE VEHICLE_MANUFACTURER_NAME  \
# 0          143031               Auto                      Ford
# 1          146501               Auto                       MCC
# 2          147314               Auto                      Ford
# 3          147382               Auto                      Opel
# 4          147392               Auto                       MCC
#
#   VEHICLE_MODEL_NAME                 VEHICLE_TYPE_NAME                VIN  \
# 0            Transit  2,2 Diesel 63kW !! kein Radio !!  WF0XXXBDFX8R74238
# 1            E-Smart                     E-Smart 30 kW  WME4513911K386156
# 2              Focus              1,6 Diesel 80kW NAVI  WF0SXXGCDSAA82712
# 3              Astra              1,7 Diesel 81kW NAVI  W0L0AHL35B2057645
# 4            E-Smart                     E-Smart 30 kW  WME4513911K448772
#
#   REGISTRATION_PLATE  SERIAL_NUMBER  KW FUEL_TYPE_NAME OWNERSHIP_TYPE  \
# 0           F-R 8018            NaN  63         Diesel  Langzeitmiete
# 1          B-SB 4460            NaN  30          Strom  Langzeitmiete
# 2           F-R 8794            NaN  80         Diesel  Langzeitmiete
# 3           F-R 8829            NaN  81         Diesel  Langzeitmiete
# 4         HH-EM 3019            NaN  30          Strom  Langzeitmiete
#
#   CAPACITY_AMOUNT ACCESS_CONTROL_COMPONENT_TYPE             COMPANY  \
# 0            60 l                           NaN  Flinkster (Endkd.)
# 1             NaN                           NaN  Flinkster (Endkd.)
# 2            52 l                           NaN  Flinkster (Endkd.)
# 3            52 l                           NaN  Flinkster (Endkd.)
# 4             NaN                           NaN  Flinkster (Endkd.)
#
#   COMPANY_GROUP                      LABEL
# 0   DB Fuhrpark  FAHRZEUG;AUTO;FORD;DIESEL
# 1   DB Fuhrpark    FAHRZEUG;AUTO;MCC;STROM
# 2   DB Fuhrpark  FAHRZEUG;AUTO;FORD;DIESEL
# 3   DB Fuhrpark  FAHRZEUG;AUTO;OPEL;DIESEL
# 4   DB Fuhrpark    FAHRZEUG;AUTO;MCC;STROM

# %% [markdown]
# ### Ausgeben der Quelldateien für Neo4J-Import
#
# > - Nur als Node

# %%
# Die Nodes für die Fahrzeuge
writeDsvFile(df_fz, 'vehicles', '|', ['VEHICLE_HAL_ID', 'VEHICLE_MODEL_NAME', 'VEHICLE_TYPE_NAME', 'VIN', 'REGISTRATION_PLATE', 'KW', 'FUEL_TYPE_NAME', 'OWNERSHIP_TYPE', 'COMPANY', 'COMPANY_GROUP', 'LABEL'], ['vehicleID:ID(VEHICLE-ID)','modelName','modelDetails','vin','registrationPlate','kw:long','fuelType','ownershipType','company','companyGroup',':LABEL'])

# %% [markdown]
# ### Lesen der Stationsinformationen

# %%
df_stations = pd.read_csv('./datasets/OPENDATA_RENTAL_ZONE_CARSHARING.csv', quotechar='"',encoding ='utf-8', sep=';')
df_stations.head()
# Out:
#    RENTAL_ZONE_HAL_ID RENTAL_ZONE_HAL_SRC               NAME  \
# 0                  38             Station   Paul-Lincke-Ufer
# 1                  79             Station         Ostbahnhof
# 2                 136             Station        Hbf Rostock
# 3                 138             Station       Hbf Schwerin
# 4                 171             Station  Hbf Aschaffenburg
#
#                 CODE          TYPE           CITY      COUNTRY  \
# 0                PLU   parkingarea         Berlin  Deutschland
# 1                OST  stationbased         Berlin  Deutschland
# 2        Hbf Rostock  stationbased        Rostock  Deutschland
# 3       Hbf Schwerin   parkingarea       Schwerin  Deutschland
# 4  Hbf Aschaffenburg  stationbased  Aschaffenburg  Deutschland
#
#              LATITUDE           LONGITUDE POI_AIRPORT_X  \
# 0  52,491966685810670  13,437334746122360          Nein
# 1  52,509446616791216  13,433682918548584          Nein
# 2  54,077917752559770  12,132610380649567          Nein
# 3  53,633873801997470  11,406887769699097          Nein
# 4  49,981667892009890   9,144830703735351          Nein
#
#   POI_LONG_DISTANCE_TRAINS_X POI_SUBURBAN_TRAINS_X POI_UNDERGROUND_X ACTIVE_X  \
# 0                       Nein                  Nein              Nein     Nein
# 1                         Ja                  Nein              Nein       Ja
# 2                         Ja                    Ja              Nein       Ja
# 3                         Ja                  Nein              Nein       Ja
# 4                         Ja                  Nein              Nein       Ja
#
#               COMPANY COMPANY_GROUP
# 0  Flinkster (Endkd.)   DB Fuhrpark
# 1  Flinkster (Endkd.)   DB Fuhrpark
# 2  Flinkster (Endkd.)   DB Fuhrpark
# 3  Flinkster (Endkd.)   DB Fuhrpark
# 4  Flinkster (Endkd.)   DB Fuhrpark

# %% [markdown]
# ### Analyse: RENTAL_ZONE_HAL_SRC
#
# > Hat die Spalte eine Relevanz?
#
# > Da in der Spalte nur ein Wert vorkommt: Nicht

# %%
df_stations['RENTAL_ZONE_HAL_SRC'].unique()
# Out:
# array(['Station'], dtype=object)

# %% [markdown]
# ### Analyse: COUNTRY
#
# > Hat die Spalte eine Relevanz?
#
# > Da in der Spalte nur ein Wert vorkommt: Nicht
#
# > Aus dem Grund wird nur die Stadt verwendet

# %%
df_stations['COUNTRY'].unique()
# Out:
# array(['Deutschland'], dtype=object)

# %% [markdown]
# ### Analyse: CITY
#
# > Wie sollte die Spalte verwendet werden?
#
# > In der Spalte kommen auch Städte mit Leerzeichen, Minus, Klammer und Slash vor
#
# > Zunächst wird die Information als Attribut umgesetzt.

# %%
import functools as ft
ft.reduce( \
    lambda x, y: x & y , \
        map( \
            lambda x: len(x.split())==1 \
                , df_stations['CITY'].unique()) \
    )
# Out:
# False

# %%
list(filter( \
    lambda x: len(x.split())>1 \
    , df_stations['CITY'].unique() \
))
# Out:
# ['Frankfurt am Main',
#  'München (DB-intern)',
#  'Mannheim (BB)',
#  'Wiesbaden (BB)',
#  'Westerland auf Sylt',
#  'Flugh. Berlin',
#  'Flugh. München',
#  'Flugh. Frankfurt',
#  'Flugh. Stuttgart/Echterdingen',
#  'Au (Sieg)',
#  'Homburg / Saar',
#  'Mülheim / Ruhr',
#  'Losheim am See',
#  'St. Wendel',
#  'St. Ingbert',
#  'DB Ein-/Aussteuerung']

# %% [markdown]
# ### Analyse: TYPE
#
# > Hat die Spalte eine Relevanz?
#
# > Ja, die Spalte eignet sich als Label

# %%
df_stations['TYPE'].unique()
# Out:
# array(['parkingarea', 'stationbased', 'freefloating'], dtype=object)

# %%
df_stations['LABEL'] = df_stations.apply(getLabel, axis=1, nodeName='RENTAL_ZONE')
df_stations.head()
# Out:
#    RENTAL_ZONE_HAL_ID RENTAL_ZONE_HAL_SRC               NAME  \
# 0                  38             Station   Paul-Lincke-Ufer
# 1                  79             Station         Ostbahnhof
# 2                 136             Station        Hbf Rostock
# 3                 138             Station       Hbf Schwerin
# 4                 171             Station  Hbf Aschaffenburg
#
#                 CODE          TYPE           CITY      COUNTRY  \
# 0                PLU   parkingarea         Berlin  Deutschland
# 1                OST  stationbased         Berlin  Deutschland
# 2        Hbf Rostock  stationbased        Rostock  Deutschland
# 3       Hbf Schwerin   parkingarea       Schwerin  Deutschland
# 4  Hbf Aschaffenburg  stationbased  Aschaffenburg  Deutschland
#
#              LATITUDE           LONGITUDE POI_AIRPORT_X  \
# 0  52,491966685810670  13,437334746122360          Nein
# 1  52,509446616791216  13,433682918548584          Nein
# 2  54,077917752559770  12,132610380649567          Nein
# 3  53,633873801997470  11,406887769699097          Nein
# 4  49,981667892009890   9,144830703735351          Nein
#
#   POI_LONG_DISTANCE_TRAINS_X POI_SUBURBAN_TRAINS_X POI_UNDERGROUND_X ACTIVE_X  \
# 0                       Nein                  Nein              Nein     Nein
# 1                         Ja                  Nein              Nein       Ja
# 2                         Ja                    Ja              Nein       Ja
# 3                         Ja                  Nein              Nein       Ja
# 4                         Ja                  Nein              Nein       Ja
#
#               COMPANY COMPANY_GROUP                         LABEL
# 0  Flinkster (Endkd.)   DB Fuhrpark  STATION;PARKINGAREA;INACTIVE
# 1  Flinkster (Endkd.)   DB Fuhrpark   STATION;STATIONBASED;ACTIVE
# 2  Flinkster (Endkd.)   DB Fuhrpark   STATION;STATIONBASED;ACTIVE
# 3  Flinkster (Endkd.)   DB Fuhrpark    STATION;PARKINGAREA;ACTIVE
# 4  Flinkster (Endkd.)   DB Fuhrpark   STATION;STATIONBASED;ACTIVE

# %% [markdown]
# ### Header für die Station-Elemente
# > rentalZoneID:ID(RENTAL-ZONE-ID)|name|code|type|city|latitude:float|longtitude:float|poiAirpor|poiLongDistanceTrains|poiSuburbanTrains|poiUnderground|:LABEL

# %% [markdown]
# ### Ausgeben der Quelldateien für Neo4J-Import
#
# > - Stationen

# %%
# Die Nodes für die Fahrzeuge
writeDsvFile(df_stations, 'rentalZones', '|', \
             ['RENTAL_ZONE_HAL_ID', 'NAME', 'CODE', 'TYPE', 'CITY', 'LATITUDE', \
                  'LONGTITUDE', 'POI_AIRPORT_X', 'POI_LONG_DISTANCE_TRAINS_X', 'POI_SUBURBAN_TRAINS_X', \
                  'POI_UNDERGROUND_X', 'LABEL']\
             , [ 'rentalZoneID:ID(RENTAL-ZONE-ID)', 'name', 'code', 'type', 'city', 'latitude:float', \
                    'longtitude:float', 'poiAirport', 'poiLongDistanceTrains', 'poiSuburbanTrains', \
                    'poiUnderground', ':LABEL'])

# %% [markdown]
# ### Lesen der Buchungsinformationen

# %%
#df_cat.set_index("HAL_ID", inplace= True)
#df_cat.head()

# %%
df_booking = pd.read_csv('./datasets/OPENDATA_BOOKING_CARSHARING.csv', quotechar='"',encoding ='utf-8', sep=';')
df_booking.head()
# Out:
#    BOOKING_HAL_ID  CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# 0        17842196           100012          150359
# 1        18270895           100003          149335
# 2        19054992           100012          151333
# 3        19057626           100003          149540
# 4        19313282           100001          150574
#
#                             CUSTOMER_HAL_ID         DATE_BOOKING  \
# 0  9680D41CFEFE292240253676FF6DD6C242B98EFD  2013-06-05 08:49:33
# 1  045B17DDFAA4DCE1751DF14B2DFC2C3106C5E788  2013-06-25 14:12:08
# 2  645B3B221397740C5DD3ACE9915B28D717697D1F  2013-08-01 07:20:47
# 3  00DF8A75463E3424010AF22F5292FB9499DBEFBD  2013-08-01 09:22:07
# 4  6551685BE2457EC2944877C65423089CDD6EA6C2  2013-08-13 10:28:38
#
#              DATE_FROM           DATE_UNTIL COMPUTE_EXTRA_BOOKING_FEE  \
# 0  2014-01-12 13:00:00  2014-01-12 14:30:00                      Nein
# 1  2014-05-06 13:30:00  2014-05-06 19:00:00                      Nein
# 2  2014-06-14 14:00:00  2014-06-22 10:30:00                      Nein
# 3  2014-02-01 15:00:00  2014-02-08 15:00:00                      Nein
# 4  2014-05-16 14:45:00  2014-05-16 22:00:00                        Ja
#
#   TRAVERSE_USE  DISTANCE    START_RENTAL_ZONE  START_RENTAL_ZONE_HAL_ID  \
# 0         Nein      14.0  Bernkasteler Straße                    401768
# 1         Nein      84.0        ZOB Oldenburg                    400346
# 2         Nein    1036.0        Hbf Stralsund                     32961
# 3         Nein     681.0  Donnersbergerbrücke                    401104
# 4           Ja      60.0            Hbf Fulda                    404524
#
#        END_RENTAL_ZONE  END_RENTAL_ZONE_HAL_ID RENTAL_ZONE_HAL_SRC  \
# 0  Bernkasteler Straße                  401768             Station
# 1        ZOB Oldenburg                  400346             Station
# 2        Hbf Stralsund                   32961             Station
# 3  Donnersbergerbrücke                  401104             Station
# 4            Hbf Fulda                  404524             Station
#
#    CITY_RENTAL_ZONE TECHNICAL_INCOME_CHANNEL
# 0              Köln                 Internet
# 1  Oldenburg (Oldb)                 Internet
# 2         Stralsund                 Internet
# 3           München                 Internet
# 4             Fulda                      NaN

# %% [markdown]
# ### Aufnehmen der Buchungsinformationen

# %%
#List unique values in the df['name'] column
df_booking.TECHNICAL_INCOME_CHANNEL.unique()
# Out:
# array(['Internet', nan, 'BwCarsharing iPhone', 'Bahn_de_2',
#        'Multicity iPhone', 'Multicity Android', 'Onesto_Bahn',
#        'ford2go Android', 'Flinkster iPhone', 'ICS-Server',
#        'ford2go iPhone', 'BwCarsharing Android', 'Flinkster Windows',
#        'einfachMobil iPhone', 'API', 'Flinkster Android', 'teilAuto',
#        'Scouter 255 Android 2Denker', 'Scouter 255 Web Praegnanz',
#        'einfachMobil Android', 'Scouter 255 iOS 2Denker',
#        'Scouter 255 Windows 2Denker', 'BwFPS Dispo Testzugang',
#        'BwFPS Portal Web', 'Broker HAL', 'Book-n-Drive iPhone',
#        'BwFPS Dispotool', 'HALAPI Teilauto', 'Book-n-Drive Android',
#        'Flinkster - Mobility Map', 'BwCarsharing WindowsPhone',
#        'Flinkster Connect', 'Flinkster E-Wald', 'Ford2Go Web',
#        'Flinkster Carjump', 'Ford Carsharing FordPass', 'EMIL Carsharing',
#        'Flinkster Drive Carsharing', 'Stuttgart Service Card'], dtype=object)

# %%
df_booking['INCOME_CHANNEL_NAME'] = df_booking.agg({'TECHNICAL_INCOME_CHANNEL' : lambda x: trimName(x)})

# %%
df_booking.INCOME_CHANNEL_NAME.head()
# Out:
# BOOKING_HAL_ID
# 17842196    'Internet'
# 18270895    'Internet'
# 19054992    'Internet'
# 19057626    'Internet'
# 19313282           nan
# Name: INCOME_CHANNEL_NAME, dtype: object

# %%
df_booking.set_index("BOOKING_HAL_ID", inplace= True)
df_booking.head()
# Out:
#                 CATEGORY_HAL_ID  VEHICLE_HAL_ID  \
# BOOKING_HAL_ID
# 17842196                 100012          150359
# 18270895                 100003          149335
# 19054992                 100012          151333
# 19057626                 100003          149540
# 19313282                 100001          150574
#
#                                          CUSTOMER_HAL_ID         DATE_BOOKING  \
# BOOKING_HAL_ID
# 17842196        9680D41CFEFE292240253676FF6DD6C242B98EFD  2013-06-05 08:49:33
# 18270895        045B17DDFAA4DCE1751DF14B2DFC2C3106C5E788  2013-06-25 14:12:08
# 19054992        645B3B221397740C5DD3ACE9915B28D717697D1F  2013-08-01 07:20:47
# 19057626        00DF8A75463E3424010AF22F5292FB9499DBEFBD  2013-08-01 09:22:07
# 19313282        6551685BE2457EC2944877C65423089CDD6EA6C2  2013-08-13 10:28:38
#
#                           DATE_FROM           DATE_UNTIL  \
# BOOKING_HAL_ID
# 17842196        2014-01-12 13:00:00  2014-01-12 14:30:00
# 18270895        2014-05-06 13:30:00  2014-05-06 19:00:00
# 19054992        2014-06-14 14:00:00  2014-06-22 10:30:00
# 19057626        2014-02-01 15:00:00  2014-02-08 15:00:00
# 19313282        2014-05-16 14:45:00  2014-05-16 22:00:00
#
#                COMPUTE_EXTRA_BOOKING_FEE TRAVERSE_USE  DISTANCE  \
# BOOKING_HAL_ID
# 17842196                            Nein         Nein      14.0
# 18270895                            Nein         Nein      84.0
# 19054992                            Nein         Nein    1036.0
# 19057626                            Nein         Nein     681.0
# 19313282                              Ja           Ja      60.0
#
#                   START_RENTAL_ZONE  START_RENTAL_ZONE_HAL_ID  \
# BOOKING_HAL_ID
# 17842196        Bernkasteler Straße                    401768
# 18270895              ZOB Oldenburg                    400346
# 19054992              Hbf Stralsund                     32961
# 19057626        Donnersbergerbrücke                    401104
# 19313282                  Hbf Fulda                    404524
#
#                     END_RENTAL_ZONE  END_RENTAL_ZONE_HAL_ID  \
# BOOKING_HAL_ID
# 17842196        Bernkasteler Straße                  401768
# 18270895              ZOB Oldenburg                  400346
# 19054992              Hbf Stralsund                   32961
# 19057626        Donnersbergerbrücke                  401104
# 19313282                  Hbf Fulda                  404524
#
#                RENTAL_ZONE_HAL_SRC  CITY_RENTAL_ZONE TECHNICAL_INCOME_CHANNEL  \
# BOOKING_HAL_ID
# 17842196                   Station              Köln                 Internet
# 18270895                   Station  Oldenburg (Oldb)                 Internet
# 19054992                   Station         Stralsund                 Internet
# 19057626                   Station           München                 Internet
# 19313282                   Station             Fulda                      NaN
#
#                INCOME_CHANNEL_NAME
# BOOKING_HAL_ID
# 17842196                'Internet'
# 18270895                'Internet'
# 19054992                'Internet'
# 19057626                'Internet'
# 19313282                       nan

# %% [markdown]
# ### Technical income channel
#
# Möglicher Umgang mit den Informationen über die Quelle (Technical income channel) der Bestellung:
#
# > Als Node mit weiteren Informationen/Beziehungen:
# > - Es liegen Detail-Informationen über die Quelle vor und die Informationen sind fachlich in Bezug auf die Haltung der Datenrelevant. Notwendige Aufwände:
# >   - Integrieren der Detail-Informationen
# >   - ID-Namespace für die Nodes
# >   - Klärung der notwendige Beziehungen
#
# > Als Label in einer Buchung:
# > - Es liegen keine Detail-Informationen über die Quelle vor. Notwendige Aufwände:
# >   - Die Quellbenennungen Label-Fähig machen (Reduktion auf ein Wort)
# >   - Die Labelnamen als zusätzliche Spalte in df_booking aufnehmen.

# %% [markdown]
# ### Referenzierte Informationen in einer Buchung:
#
# > CATEGORY_HAL_ID -> Kategorie
#
# > VEHICLE_HAL_ID -> Fahrzeug
#
# > CUSTOMER_HAL_ID -> Kunde (Datensätze nicht verfügbar)
#
# > START_RENTAL_ZONE_HAL_ID -> Abholstation
#
# > END_RENTAL_ZONE_HAL_ID -> Rückgabestation

# %%
df_cat_labels = df_cat.drop(['CATEGORY', 'COMPANY', 'COMPANY_GROUP', 'PARENT_LABEL', 'LABEL', 'PARENT_ID', 'REL_TYPE_CAT_PCAT'], axis=1)
df_booking_cat = pd.merge(df_booking, df_cat_labels, left_on='CATEGORY_HAL_ID', right_on='HAL_ID') \
                    .drop(['CUSTOMER_HAL_ID','HAL_ID','RENTAL_ZONE_HAL_SRC'], axis=1)
df_booking_cat.head()
# Out:
#    CATEGORY_HAL_ID  VEHICLE_HAL_ID                           CUSTOMER_HAL_ID  \
# 0           100012          150359  9680D41CFEFE292240253676FF6DD6C242B98EFD
# 1           100012          151333  645B3B221397740C5DD3ACE9915B28D717697D1F
# 2           100012          150359  9680D41CFEFE292240253676FF6DD6C242B98EFD
# 3           100012          150715  E1B1BF157BDEF3542D79DC7EDF30437B9DC69B4A
# 4           100012          150782  CAD3A8B07B1103B402AB30FA2EA1925821A6EABE
#
#           DATE_BOOKING            DATE_FROM           DATE_UNTIL  \
# 0  2013-06-05 08:49:33  2014-01-12 13:00:00  2014-01-12 14:30:00
# 1  2013-08-01 07:20:47  2014-06-14 14:00:00  2014-06-22 10:30:00
# 2  2013-09-15 12:19:14  2014-01-05 14:00:00  2014-01-05 15:30:00
# 3  2013-09-17 17:59:03  2014-01-11 09:45:00  2014-01-11 16:15:00
# 4  2013-10-07 08:29:51  2014-03-26 18:00:00  2014-03-27 06:30:00
#
#   COMPUTE_EXTRA_BOOKING_FEE TRAVERSE_USE  DISTANCE  \
# 0                      Nein         Nein      14.0
# 1                      Nein         Nein    1036.0
# 2                      Nein         Nein       0.0
# 3                      Nein         Nein       0.0
# 4                      Nein         Nein       0.0
#
#               START_RENTAL_ZONE  START_RENTAL_ZONE_HAL_ID  \
# 0           Bernkasteler Straße                    401768
# 1                 Hbf Stralsund                     32961
# 2           Bernkasteler Straße                    401768
# 3  Hbf 1 Siegburg (Wilhelmstr.)                    400263
# 4                 Hbf Offenburg                    400575
#
#                 END_RENTAL_ZONE  END_RENTAL_ZONE_HAL_ID RENTAL_ZONE_HAL_SRC  \
# 0           Bernkasteler Straße                  401768             Station
# 1                 Hbf Stralsund                   32961             Station
# 2           Bernkasteler Straße                  401768             Station
# 3  Hbf 1 Siegburg (Wilhelmstr.)                  400263             Station
# 4                 Hbf Offenburg                  400575             Station
#
#   CITY_RENTAL_ZONE TECHNICAL_INCOME_CHANNEL INCOME_CHANNEL_NAME  \
# 0             Köln                 Internet          'Internet'
# 1        Stralsund                 Internet          'Internet'
# 2             Köln                 Internet          'Internet'
# 3         Siegburg                 Internet          'Internet'
# 4        Offenburg                 Internet          'Internet'
#
#   PARENT_CATEGORY
# 0    Sonderklasse
# 1    Sonderklasse
# 2    Sonderklasse
# 3    Sonderklasse
# 4    Sonderklasse
